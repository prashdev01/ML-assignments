# %% [markdown]
# # **Q1. Explain the concept of R-squared in linear regression models. How is it calculated, and what does it represent?**

# %% [markdown]
# **R-squared (Coefficient of Determination) in Linear Regression:**
#
# R-squared is a statistical measure that represents the proportion of the variance in the dependent variable (\(Y\)) that is explained by the independent variable(s) in a linear regression model. It ranges from 0 to 1, with higher values indicating a better fit of the model to the data.
#
# **Calculation of R-squared:**
#
# 1. **Total Sum of Squares (SST):**
#    - Calculate the total sum of squares, which represents the total variability in the dependent variable.
#    \[ SST = \sum_{i} (Y_i - \bar{Y})^2 \]
#    - \(\bar{Y}\) is the mean of the dependent variable.
#
# 2. **Residual Sum of Squares (SSR):**
#    - Calculate the residual sum of squares, which represents the unexplained variability in the dependent variable.
#    \[ SSR = \sum_{i} (Y_i - \hat{Y}_i)^2 \]
#    - \(\hat{Y}_i\) is the predicted value of \(Y_i\) based on the regression model.
#
# 3. **R-squared Calculation:**
#    - R-squared is calculated as the proportion of the total sum of squares that is explained by the model.
#    \[ R^2 = 1 - \frac{SSR}{SST} \]
#
# **Interpretation of R-squared:**
#
# - **Value Range:**
#   - R-squared values range from 0 to 1. A value of 0 indicates that the model does not explain any variability, while a value of 1 indicates that the model explains all the variability.
#
# - **Percentage Explanation:**
#   - R-squared is often interpreted as the percentage of the dependent variable's variability explained by the independent variable(s).
#
# - **Goodness of Fit:**
#   - A higher R-squared suggests a better fit of the model to the data, as it indicates a greater proportion of the variability in the dependent variable is accounted for by the model.
#
# - **Caution:**
#   - While a high R-squared is desirable, it's important to consider other factors like model complexity, overfitting, and the context of the data.
#
# **Example:**
#
# If R-squared is 0.8, it means that 80% of the variability in the dependent variable is explained by the independent variable(s) in the model, and the remaining 20% is unexplained or due to random variability.

# %% [markdown]
# # **Q2. Define adjusted R-squared and explain how it differs from the regular R-squared.**

# %% [markdown]
# **Adjusted R-squared in Linear Regression:**
#
# Adjusted R-squared is a modified version of the regular R-squared that accounts for the number of predictors (independent variables) in the model. While R-squared tells you the proportion of the variance in the dependent variable that is explained by the model, adjusted R-squared adjusts this value based on the number of predictors and the sample size.
#
# **Calculation of Adjusted R-squared:**
#
# \[ \text{Adjusted R}^2 = 1 - \left( \frac{(1 - R^2) \cdot (n - 1)}{n - k - 1} \right) \]
#
# - \( R^2 \): Regular R-squared.
# - \( n \): Number of observations.
# - \( k \): Number of predictors.
#
# **Differences from Regular R-squared:**
#
# 1. **Penalty for Additional Predictors:**
#    - Adjusted R-squared penalizes the inclusion of additional predictors in the model. It decreases when adding predictors if they do not significantly contribute to explaining the variance.
#
# 2. **Accounts for Sample Size:**
#    - Adjusted R-squared takes into account both the number of predictors and the sample size, providing a more reliable measure of goodness of fit for models with different numbers of predictors.
#
# 3. **Prevents Overestimation:**
#    - Regular R-squared tends to increase when more predictors are added, even if they do not significantly improve the model. Adjusted R-squared prevents this overestimation by considering the number of predictors and the sample size.
#
# **Interpretation:**
#
# - A higher adjusted R-squared indicates a better balance between model fit and model simplicity, as it penalizes models with too many predictors that do not contribute substantially to explaining the variability in the dependent variable.
#
# **Example:**
#
# Suppose a model has an adjusted R-squared of 0.75. It means that, after adjusting for the number of predictors and sample size, 75% of the variability in the dependent variable is explained by the predictors in the model. The adjusted R-squared would decrease if additional predictors were included that did not significantly contribute to the model's explanatory power.

# %% [markdown]
# # **Q3. When is it more appropriate to use adjusted R-squared?**

# %% [markdown]
# Adjusted R-squared is more appropriate to use when you want to assess the goodness of fit of a regression model while taking into account the number of predictors (independent variables) in the model and the sample size. Here are situations where adjusted R-squared is particularly useful:
#
# 1. **Comparing Models with Different Numbers of Predictors:**
#    - Adjusted R-squared allows for a fair comparison between models with different numbers of predictors. It penalizes the inclusion of additional predictors that do not substantially improve the model's explanatory power.
#
# 2. **Model Selection:**
#    - When considering multiple models with different sets of predictors, adjusted R-squared helps in selecting the model that achieves a good balance between explanatory power and simplicity. It discourages the inclusion of unnecessary predictors.
#
# 3. **Avoiding Overfitting:**
#    - Adjusted R-squared is useful for assessing whether adding more predictors improves the model beyond what would be expected by chance. It helps prevent overfitting by penalizing models that may fit the training data too closely.
#
# 4. **Sample Size Considerations:**
#    - In situations where the sample size is relatively small, adjusted R-squared is especially important. Regular R-squared tends to increase with additional predictors in smaller samples, even when the improvement is minimal. Adjusted R-squared accounts for this and provides a more conservative assessment.
#
# 5. **Complex Models:**
#    - When dealing with complex models, especially those with a large number of predictors, adjusted R-squared provides a more realistic evaluation of the model's goodness of fit. It discourages the inclusion of predictors that do not contribute meaningfully.
#
# In summary, adjusted R-squared is particularly valuable when you want a more nuanced evaluation of model fit, considering both the explanatory power of the model and the complexity introduced by the number of predictors, especially in the context of model selection and comparisons.

# %% [markdown]
# # **Q4. What are RMSE, MSE, and MAE in the context of regression analysis? How are these metrics calculated, and what do they represent?**

# %% [markdown]
# **RMSE (Root Mean Squared Error), MSE (Mean Squared Error), and MAE (Mean Absolute Error) in Regression Analysis:**
#
# These are commonly used metrics to evaluate the performance of regression models by measuring the accuracy of the predicted values compared to the actual values.
#
# 1. **Mean Absolute Error (MAE):**
#    - **Calculation:**
#      \[ MAE = \frac{1}{n} \sum_{i=1}^{n} \left| Y_i - \hat{Y}_i \right| \]
#    - \( Y_i \): Actual value.
#    - \( \hat{Y}_i \): Predicted value.
#    - \( n \): Number of observations.
#
#    - **Interpretation:**
#      - Represents the average absolute difference between the actual and predicted values. It is less sensitive to outliers compared to squared error metrics.
#
# 2. **Mean Squared Error (MSE):**
#    - **Calculation:**
#      \[ MSE = \frac{1}{n} \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 \]
#    - \( Y_i \): Actual value.
#    - \( \hat{Y}_i \): Predicted value.
#    - \( n \): Number of observations.
#
#    - **Interpretation:**
#      - Represents the average squared difference between the actual and predicted values. Squaring gives more weight to larger errors.
#
# 3. **Root Mean Squared Error (RMSE):**
#    - **Calculation:**
#      [ RMSE = \sqrt{MSE} \]
#    - \( MSE \): Mean Squared Error.
#
#    - **Interpretation:**
#      - Represents the square root of the average squared difference between the actual and predicted values. It is in the same unit as the dependent variable, providing a more interpretable measure than MSE.
#
# **Comparisons:**
#
# - **MAE:**
#   - Measures average absolute errors.
#   - Less sensitive to outliers.
#   - Provides a direct interpretation of average prediction error.
#
# - **MSE:**
#   - Measures average squared errors.
#   - Sensitive to outliers due to squaring.
#   - Larger errors have more impact.
#
# - **RMSE:**
#   - Same as MSE but in the same unit as the dependent variable.
#   - Provides an interpretable measure of the average prediction error.
#
# **Selection Criteria:**
# - **MAE:** Use when errors have a linear impact, and outliers should not be heavily penalized.
# - **MSE/RMSE:** Use when larger errors should be penalized more or when working with a model that assumes normally distributed errors.
#
# When choosing between these metrics, consider the specific goals of your analysis and the impact of outliers on the evaluation of model performance.

# %% [markdown]
# # **Q5. Discuss the advantages and disadvantages of using RMSE, MSE, and MAE as evaluation metrics in regression analysis.**

# %% [markdown]
# **Mean Absolute Error (MAE):**
#
# **Advantages:**
# - Robust to outliers.
# - Easy to interpret.
#
# **Disadvantages:**
# - Treats all errors equally.
# - Not differentiable at zero.
#
# ---
#
# **Mean Squared Error (MSE) and Root Mean Squared Error (RMSE):**
#
# **Advantages:**
# - Penalizes larger errors.
# - Mathematically convenient (differentiable).
#
# **Disadvantages:**
# - Sensitive to outliers.
# - Interpretability (MSE).
# - Assumes normal distribution of errors.
#
# ---
#
# **Considerations:**
# - Choose based on outlier sensitivity and interpretability.
# - MSE/RMSE for larger errors; MAE for robustness.
# - RMSE if optimization algorithms require differentiability.

# %% [markdown]
# # **Q6. Explain the concept of Lasso regularization. How does it differ from Ridge regularization, and when is it more appropriate to use?**

# %% [markdown]
# **Lasso Regularization in Linear Regression:**
#
# Lasso (Least Absolute Shrinkage and Selection Operator) regularization is a technique used in linear regression to prevent overfitting and improve the model's generalization performance. It adds a penalty term to the linear regression cost function, encouraging the model to prefer simpler models with fewer predictor variables.
#
#
# **Differences from Ridge Regularization:**
#
# 1. **Penalty Term:**
#    - Lasso uses the absolute values of the regression coefficients (\(\theta_i\)), leading to sparsity in the solution. It tends to drive some coefficients to exactly zero.
#    - Ridge, on the other hand, uses the squared values of the coefficients, penalizing large coefficients but rarely setting them exactly to zero.
#
# 2. **Variable Selection:**
#    - Lasso's penalty term encourages variable selection by setting some coefficients to exactly zero. It acts as a feature selection method.
#    - Ridge may shrink coefficients but rarely eliminates them entirely.
#
# 3. **Solution Space:**
#    - Lasso tends to produce sparse solutions with a smaller number of important predictors.
#    - Ridge tends to shrink coefficients toward zero but keeps all predictors in the model.
#
# **When to Use Lasso Regularization:**
#
# - **Sparse Solutions:**
#   - When you suspect that many of the predictors are irrelevant or can be safely excluded from the model.
#
# - **Feature Selection:**
#   - When you want the regularization process to automatically perform feature selection and produce a model with a subset of the most important predictors.
#
# - **Interpretability:**
#   - When interpretability is important, and having a subset of predictors with non-zero coefficients aligns with the problem context.
#
# - **Dealing with High-Dimensional Data:**
#   - Lasso is particularly useful in situations where you have a large number of predictors (high-dimensional data).
#
# **Considerations:**
#
# - **Choice between Lasso and Ridge:**
#   - If you suspect many features are irrelevant, use Lasso for automatic feature selection.
#   - If you want to shrink all coefficients but not exclude any, consider Ridge.
#
# - **Hyperparameter Tuning:**
#   - The choice of the regularization strength (\(\alpha\)) is crucial and may require tuning through techniques like cross-validation.
#
# In summary, Lasso regularization is suitable when you want to promote sparsity in the model, perform automatic feature selection, or deal with high-dimensional data. It is a valuable tool when interpretability and simplicity in the model are priorities.

# %% [markdown]
# # **Q7. How do regularized linear models help to prevent overfitting in machine learning? Provide an example to illustrate.**

# %% [markdown]
# Regularized linear models, such as Ridge and Lasso regression, help prevent overfitting in machine learning by adding a penalty term to the cost function. This penalty discourages the model from fitting the training data too closely, which can lead to overfitting. Here's a brief explanation and an example:
#
# **Overfitting in Linear Regression:**
# - In linear regression, a model with too many features or high-degree polynomial terms can fit the training data extremely well.
# - However, this may result in poor generalization to new, unseen data.
#
# **Regularization in Linear Models:**
# - Regularized linear models introduce a penalty term that discourages overly complex models with large coefficients.
# - The penalty is added to the cost function, influencing the optimization process during model training.
#
#
# **Illustration:**
# Consider a situation where you have a dataset with only one feature, and you fit a high-degree polynomial regression (potentially leading to overfitting):
#
#
# - Without regularization, the model might perfectly fit the training data by assigning large coefficients to high-degree terms.
# - Ridge regression introduces a penalty term that discourages large coefficients, influencing the optimization process.
# - As a result, Ridge regression helps prevent overfitting by controlling the magnitude of the coefficients.
#
#
# In the plot, the blue dashed line represents the overfitting without regularization, and the orange line represents the model with Ridge regularization. Ridge regularization helps prevent extreme coefficients, resulting in a more generalizable model.

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + 1.5 * X**2 + np.random.randn(100, 1)

# Polynomial regression without regularization
model_no_reg = make_pipeline(PolynomialFeatures(degree=10), Ridge(alpha=0))
model_no_reg.fit(X, y)

# Polynomial regression with regularization (Ridge)
model_with_reg = make_pipeline(PolynomialFeatures(degree=10), Ridge(alpha=1))
model_with_reg.fit(X, y)

# Plot the results
X_new = np.linspace(0, 2, 100).reshape(100, 1)
y_no_reg = model_no_reg.predict(X_new)
y_with_reg = model_with_reg.predict(X_new)

plt.scatter(X, y, label='Training data')
plt.plot(X_new, y_no_reg, label='No Regularization', linestyle='--', linewidth=2)
plt.plot(X_new, y_with_reg, label='Ridge Regularization', linewidth=2)
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Regularization in Polynomial Regression')
plt.show()

# %% [markdown]
# # **Q8. Discuss the limitations of regularized linear models and explain why they may not always be the best choice for regression analysis.**

# %% [markdown]
# **Limitations of Regularized Linear Models:**
#
# 1. **Loss of Interpretability:**
#    - Regularization can shrink coefficients, making them harder to interpret, especially when using L1 regularization (Lasso), which can lead to sparse solutions.
#
# 2. **Sensitivity to Hyperparameters:**
#    - The performance of regularized models is sensitive to the choice of hyperparameters (e.g., \(\alpha\) in Ridge or Lasso). Fine-tuning is crucial but can be challenging.
#
# 3. **Assumption of Linearity:**
#    - Regularized linear models assume a linear relationship between features and the target. They might not perform well when the true relationship is highly non-linear.
#
# 4. **Limited Handling of Irrelevant Features:**
#    - While Lasso can encourage sparsity, it may not handle a large number of irrelevant features well, and some irrelevant features might still get non-zero coefficients.
#
# 5. **Data Scaling Sensitivity:**
#    - Regularized models are sensitive to the scale of features. It's essential to scale features appropriately before applying regularization.
#
# 6. **May Not Capture Complex Patterns:**
#    - In situations where the relationship between predictors and the target is genuinely complex, rigidly linear models may not capture the complexity as well as non-linear models.
#
# **When Regularized Models May Not Be Ideal:**
#
# 1. **Small Datasets:**
#    - In small datasets, regularization might lead to an excessive shrinkage of coefficients, potentially resulting in an underfit model.
#
# 2. **Non-Linear Relationships:**
#    - When the true relationship between predictors and the target is non-linear, regularized linear models might not capture the complexity well.
#
# 3. **Interpretability Priority:**
#    - If the primary goal is to maintain the interpretability of coefficients, non-regularized linear models might be preferred.
#
# 4. **Feature Engineering Emphasis:**
#    - In cases where thorough feature engineering and selection are performed, and the risk of overfitting is carefully managed, regularized models might be unnecessary.
#
# 5. **Domain-Specific Considerations:**
#    - Depending on the domain and problem at hand, certain models, like decision trees or ensemble methods, might outperform regularized linear models.
#
# In summary, while regularized linear models offer valuable tools for preventing overfitting and handling high-dimensional data, they have limitations. The choice between regularized and non-regularized models depends on factors such as dataset size, linearity assumptions, interpretability requirements, and the nature of the relationship between predictors and the target.

# %% [markdown]
# # **Q9. You are comparing the performance of two regression models using different evaluation metrics. Model A has an RMSE of 10, while Model B has an MAE of 8. Which model would you choose as the better performer, and why? Are there any limitations to your choice of metric?**

# %% [markdown]
# In this scenario, the choice between Model A and Model B depends on the specific goals and characteristics of the problem. Let's analyze the situation:
#
# **Model A (RMSE = 10):**
# - Root Mean Squared Error (RMSE) is sensitive to larger errors due to the squaring operation in its calculation.
# - A lower RMSE suggests that smaller errors are given less weight compared to larger errors.
#
# **Model B (MAE = 8):**
# - Mean Absolute Error (MAE) treats all errors equally without giving extra weight to larger errors.
#
# **Considerations:**
# 1. **Weighting of Errors:**
#    - If the problem is such that larger errors should be penalized more, Model A (lower RMSE) might be preferred.
#
# 2. **Robustness to Outliers:**
#    - If the dataset contains outliers, MAE is generally more robust as it is less influenced by extreme values.
#
# 3. **Interpretability:**
#    - MAE is more straightforward to interpret as it represents the average absolute difference between predicted and actual values.
#
# **Limitations:**
# - **Context Matters:**
#   - The choice of metric depends on the specific context and the nature of the problem. There is no universally superior metric; it varies from one application to another.
#
# - **Impact of Outliers:**
#   - RMSE can be strongly influenced by outliers, and the choice of metric should consider the robustness of the model to extreme values.
#
# - **Problem-Specific Goals:**
#   - The decision should align with the goals of the regression task. For example, if the goal is to minimize the impact of large errors, RMSE may be more suitable.
#
# - **Trade-offs:**
#   - It's essential to recognize the trade-offs between different metrics and consider factors like interpretability, sensitivity to outliers, and the practical implications of errors.
#
# In summary, choosing between Model A and Model B depends on the specific priorities of the problem. If larger errors are of greater concern, Model A (lower RMSE) might be preferred. However, if robustness to outliers and interpretability are crucial, Model B (lower MAE) might be a better choice. Always consider the context and goals of the regression analysis.

# %% [markdown]
# # **Q10. You are comparing the performance of two regularized linear models using different types of regularization. Model A uses Ridge regularization with a regularization parameter of 0.1, while Model B uses Lasso regularization with a regularization parameter of 0.5. Which model would you choose as the better performer, and why? Are there any trade-offs or limitations to your choice of regularization method?**

# %% [markdown]
# In comparing the performance of two regularized linear models (Ridge and Lasso), the choice between Model A (Ridge) and Model B (Lasso) depends on the specific characteristics of the data and the goals of the modeling task. Let's analyze the situation:
#
# **Model A (Ridge Regularization,  α = 0.1):**
# - Ridge regularization adds a penalty term based on the sum of squared coefficients to the cost function.
# - The regularization parameter α controls the strength of the penalty, and a smaller value (0.1) indicates a milder regularization.
#
# **Model B (Lasso Regularization, α = 0.5:**
# - Lasso regularization adds a penalty term based on the sum of absolute values of coefficients to the cost function.
# - The regularization parameter (\(α\)) controls the strength of the penalty, and a larger value (0.5) indicates a stronger regularization.
#
# **Considerations:**
# 1. **Nature of Coefficient Shrinkage:**
#    - Ridge tends to shrink coefficients toward zero, but rarely sets them exactly to zero.
#    - Lasso has a tendency to produce sparse solutions by driving some coefficients to exactly zero, effectively performing feature selection.
#
# 2. **Feature Selection:**
#    - If feature selection is a priority, and it is desirable to eliminate some irrelevant predictors, Lasso might be preferred.
#
# 3. **Trade-offs:**
#    - Ridge may be more suitable when all features are potentially relevant, and a balance between regularization and maintaining all predictors is desired.
#
# **Limitations and Trade-offs:**
# - **Lasso Sparsity Advantage:**
#   - Lasso's advantage in producing sparse solutions can be a limitation when dealing with a large number of predictors, and some may be wrongly set to zero.
#
# - **Sensitivity to Features:**
#   - Lasso is sensitive to the scale of features, and careful feature scaling is often necessary.
#
# - **Impact of \(\alpha\):**
#   - The choice of the regularization parameter (\(\alpha\)) is critical. It may require fine-tuning through techniques like cross-validation.
#
# - **Interpretability:**
#   - Ridge is generally more interpretable as it does not lead to complete elimination of predictors.
#
# **Decision:**
# - If the goal is to perform feature selection and produce a sparse model, Model B (Lasso) might be preferred.
# - If maintaining all predictors while still applying regularization is essential, or if interpretability is a priority, Model A (Ridge) might be more suitable.
#
# In summary, the choice between Ridge and Lasso regularization depends on the specific goals, characteristics of the data, and the trade-offs between sparsity and maintaining all predictors. Careful consideration of these factors is crucial in making an informed decision.
